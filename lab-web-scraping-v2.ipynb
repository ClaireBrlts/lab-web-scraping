# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://books.toscrape.com/catalogue/page-1.html"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)

# %%
books = soup.find_all('article', class_='product_pod')
len(books)
# Out:
# 20

# %%
books[0].find_all("p", attrs = {"class":"star-rating"})[0]["class"][-1]
# Out:
# 'Three'

# %%
#Functions to get the product info from the home page

def get_book_rating(book):
    rating_str = book.find_all("p", attrs = {"class":"star-rating"})[0]["class"][-1]
    if rating_str == "One":
        return 1
    elif rating_str == "Two":
        return 2
    elif rating_str == "Three":
        return 3
    elif rating_str == "Four":
        return 4
    else:
        return 5
    

def get_book_price(book):
    price = book.find_all("p", attrs = {"class" :"price_color"})[0].get_text().replace("£","")
    return float(price)


def get_book_title(book):
    book_title = book.find_all("a")[-1]["title"]
    return book_title

def get_book_href(book):
    base_url = "https://books.toscrape.com/catalogue/"
    book_url = book.find_all("a")[-1]["href"]
    return base_url + book_url

# %%
#Functions to get further info from book page

def get_genre(soup_book):
    header = soup_book.find_all("ul", attrs = {"class":"breadcrumb"})
    return header[0].find_all("li")[-2].get_text().strip()

def get_upc(soup_book):
    return soup_book.find_all("td")[0].get_text()

def get_availability(soup_book):
    return soup_book.find_all("p", attrs = {"class":"instock availability"})[0].get_text().strip()

# %%
def get_page_books(page_number = 1, min_rating = 4, max_price = 20):
    url = f"https://books.toscrape.com/catalogue/page-{page_number}.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.content)

    books_dict = {}
    index = 0

    books = soup.find_all("li", attrs = {"class":"col-xs-6 col-sm-4 col-md-3 col-lg-3"})

    for book in books:
        price = get_book_price(book)
        title = get_book_title(book)
        link = get_book_href(book)
        rating = get_book_rating(book)

        if price <= max_price and rating >= min_rating:
            response_book = requests.get(link)
            soup_book = BeautifulSoup(response_book.content)

            upc = get_upc(soup_book)
            availability = get_availability(soup_book)
            genre = get_genre(soup_book)

            books_dict[index] = {"price":price,
                                "title":title,
                                "link":link,
                                "rating":rating,
                                "upc":upc,
                                "availability":availability,
                                "genre":genre}
            index += 1

    return pd.DataFrame.from_dict(books_dict, orient="index")

get_page_books(page_number=1, min_rating = 1, max_price = 70)
# Out:
#     price                                              title  \
# 0   51.77                               A Light in the Attic
# 1   53.74                                 Tipping the Velvet
# 2   50.10                                         Soumission
# 3   47.82                                      Sharp Objects
# 4   54.23              Sapiens: A Brief History of Humankind
# 5   22.65                                    The Requiem Red
# 6   33.34  The Dirty Little Secrets of Getting Your Dream...
# 7   17.93  The Coming Woman: A Novel Based on the Life of...
# 8   22.60  The Boys in the Boat: Nine Americans and Their...
# 9   52.15                                    The Black Maria
# 10  13.99     Starving Hearts (Triangular Trade Trilogy, #1)
# 11  20.66                              Shakespeare's Sonnets
# 12  17.46                                        Set Me Free
# 13  52.29  Scott Pilgrim's Precious Little Life (Scott Pi...
# 14  35.02                          Rip it Up and Start Again
# 15  57.25  Our Band Could Be Your Life: Scenes from the A...
# 16  23.88                                               Olio
# 17  37.59  Mesaerion: The Best Science Fiction Stories 18...
# 18  51.33                       Libertarianism for Beginners
# 19  45.17                            It's Only the Himalayas
#
#                                                  link  rating  \
# 0   https://books.toscrape.com/catalogue/a-light-i...       3
# 1   https://books.toscrape.com/catalogue/tipping-t...       1
# 2   https://books.toscrape.com/catalogue/soumissio...       1
# 3   https://books.toscrape.com/catalogue/sharp-obj...       4
# 4   https://books.toscrape.com/catalogue/sapiens-a...       5
# 5   https://books.toscrape.com/catalogue/the-requi...       1
# 6   https://books.toscrape.com/catalogue/the-dirty...       4
# 7   https://books.toscrape.com/catalogue/the-comin...       3
# 8   https://books.toscrape.com/catalogue/the-boys-...       4
# 9   https://books.toscrape.com/catalogue/the-black...       1
# 10  https://books.toscrape.com/catalogue/starving-...       2
# 11  https://books.toscrape.com/catalogue/shakespea...       4
# 12  https://books.toscrape.com/catalogue/set-me-fr...       5
# 13  https://books.toscrape.com/catalogue/scott-pil...       5
# 14  https://books.toscrape.com/catalogue/rip-it-up...       5
# 15  https://books.toscrape.com/catalogue/our-band-...       3
# 16  https://books.toscrape.com/catalogue/olio_984/...       1
# 17  https://books.toscrape.com/catalogue/mesaerion...       1
# 18  https://books.toscrape.com/catalogue/libertari...       2
# 19  https://books.toscrape.com/catalogue/its-only-...       2
#
#                  upc             availability               genre
# 0   a897fe39b1053632  In stock (22 available)              Poetry
# 1   90fa61229261140a  In stock (20 available)  Historical Fiction
# 2   6957f44c3847a760  In stock (20 available)             Fiction
# 3   e00eb4fd7b871a48  In stock (20 available)             Mystery
# 4   4165285e1663650f  In stock (20 available)             History
# 5   f77dbf2323deb740  In stock (19 available)         Young Adult
# 6   2597b5a345f45e1b  In stock (19 available)            Business
# 7   e72a5dfc7e9267b2  In stock (19 available)             Default
# 8   e10e1e165dc8be4a  In stock (19 available)             Default
# 9   1dfe412b8ac00530  In stock (19 available)              Poetry
# 10  0312262ecafa5a40  In stock (19 available)             Default
# 11  30a7f60cd76ca58c  In stock (19 available)              Poetry
# 12  ce6396b0f23f6ecc  In stock (19 available)         Young Adult
# 13  3b1c02bac2a429e6  In stock (19 available)      Sequential Art
# 14  a34ba96d4081e6a4  In stock (19 available)               Music
# 15  deda3e61b9514b83  In stock (19 available)               Music
# 16  feb7cc7701ecf901  In stock (19 available)              Poetry
# 17  e30f54cea9b38190  In stock (19 available)     Science Fiction
# 18  a18a4f574854aced  In stock (19 available)            Politics
# 19  a22124811bfa8350  In stock (19 available)              Travel

# %%
list_books = []
for i in range(1,51):
    df_page = get_page_books(page_number=i, max_price=20, min_rating=4)
    list_books.append(df_page)

# %%
final_df = pd.concat(list_books)
final_df.reset_index(drop=True, inplace=True)

# %%
final_df
# Out:
#     price                                              title  \
# 0   17.46                                        Set Me Free
# 1   17.66  The Four Agreements: A Practical Guide to Pers...
# 2   15.94                                     Sophie's World
# 3   14.27            Untitled Collection: Sabbath Poems 2014
# 4   19.49                                    This One Summer
# ..    ...                                                ...
# 70  19.69                                    The Zombie Room
# 71  12.34                                    The Silent Wife
# 72  12.29                                  The Girl You Lost
# 73  19.18              The Edge of Reason (Bridget Jones #2)
# 74  16.97  A Spy's Devotion (The Regency Spies of London #1)
#
#                                                  link  rating  \
# 0   https://books.toscrape.com/catalogue/set-me-fr...       5
# 1   https://books.toscrape.com/catalogue/the-four-...       5
# 2   https://books.toscrape.com/catalogue/sophies-w...       5
# 3   https://books.toscrape.com/catalogue/untitled-...       4
# 4   https://books.toscrape.com/catalogue/this-one-...       4
# ..                                                ...     ...
# 70  https://books.toscrape.com/catalogue/the-zombi...       5
# 71  https://books.toscrape.com/catalogue/the-silen...       5
# 72  https://books.toscrape.com/catalogue/the-girl-...       5
# 73  https://books.toscrape.com/catalogue/the-edge-...       4
# 74  https://books.toscrape.com/catalogue/a-spys-de...       5
#
#                  upc             availability               genre
# 0   ce6396b0f23f6ecc  In stock (19 available)         Young Adult
# 1   6258a1f6a6dcfe50  In stock (18 available)        Spirituality
# 2   6be3beb0793a53e7  In stock (18 available)          Philosophy
# 3   657fe5ead67a7767  In stock (16 available)              Poetry
# 4   51653ef291ab7ddc  In stock (16 available)      Sequential Art
# ..               ...                      ...                 ...
# 70  9c96cd1329fbd82d   In stock (1 available)             Default
# 71  b78deb463531d078   In stock (1 available)             Fiction
# 72  4280ac3eab57aa5d   In stock (1 available)             Mystery
# 73  29fc016c459aeb14   In stock (1 available)      Womens Fiction
# 74  19fec36a1dfb4c16   In stock (1 available)  Historical Fiction
#
# [75 rows x 7 columns]
